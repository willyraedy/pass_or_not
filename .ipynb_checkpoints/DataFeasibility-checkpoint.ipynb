# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 150)

# %%
bills = pd.read_csv('./IL/2019-2020_101st_General_Assembly/csv/bills.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8588 entries, 0 to 8587
# Data columns (total 14 columns):
# bill_id             8588 non-null int64
# session_id          8588 non-null int64
# bill_number         8588 non-null object
# status              8588 non-null int64
# status_desc         8584 non-null object
# status_date         8584 non-null object
# title               8588 non-null object
# description         8588 non-null object
# committee_id        8588 non-null int64
# committee           6225 non-null object
# last_action_date    8588 non-null object
# last_action         8588 non-null object
# url                 8588 non-null object
# state_link          8588 non-null object
# dtypes: int64(4), object(10)
# memory usage: 939.4+ KB

# %%
df.status_desc.value_counts()
# Out:
# Introduced    6189
# Passed        2102
# Engrossed      284
# Failed           7
# Vetoed           2
# Name: status_desc, dtype: int64

# %%
non_memorial = df[~df.title.str.contains('MEMORIAL-')]

# %%
df[df.title.str.contains('MEMORIAL-')].sort_values('committee_id')[['committee_id', 'title', 'description', 'committee']]
# Out:
#       committee_id                         title  \
# 4272             0     MEMORIAL-SEN. TOM JOHNSON
# 8175             0   MEMORIAL-STANLEY E. FURLONG
# 8176             0    MEMORIAL-JOSEPH R. VERONDA
# 8177             0    MEMORIAL-KENNETH J. WOMACK
# 8178             0    MEMORIAL-RICHARD E. DONLIN
# ...            ...                           ...
# 7830             0     MEMORIAL-WILLIAM F. MERNA
# 7812             0      MEMORIAL-ANNABEL ABRAHAM
# 8519             0    MEMORIAL-MARY ALICE PHELON
# 4846           235         MEMORIAL-JOHN L. MOON
# 4690           235  MEMORIAL-U.S. REP. DAN CRANE
#
#                                             description    committee
# 4272  Mourns the passing of former Illinois State Se...          NaN
# 8175  Mourns the death of Stanley Emmett Furlong of ...          NaN
# 8176  Mourns the death of Joseph R. "Joe" Veronda of...          NaN
# 8177  Mourns the death of Kenneth J. "Ken" Womack of...          NaN
# 8178  Mourns the death of Richard E. "Dick" Donlin o...          NaN
# ...                                                 ...          ...
# 7830    Mourns the death of William F. Merna of Canton.          NaN
# 7812               Mourns the death of Annabel Abraham.          NaN
# 8519           Mourns the passing of Mary Alice Phelon.          NaN
# 4846     Mourns the death of John Leroy Moon of Macomb.  House Rules
# 4690  Mourns the death of former United States Repre...  House Rules
#
# [977 rows x 4 columns]

# %%
non_memorial[non_memorial.title.str.contains('MEMORIAL')]
# Out:
#       bill_id  session_id bill_number  status status_desc status_date  \
# 199   1144342        1630      HB0200       1  Introduced  2019-01-09
# 4056  1301559        1630      HB4057       1  Introduced  2020-01-10
# 4213  1317357        1630      HB4214       1  Introduced  2020-01-22
# 4537  1249942        1630      HR0278       4      Passed  2019-04-09
# 4930  1317262        1630      HR0671       1  Introduced  2020-01-22
# 4950  1165294        1630     HJR0014       2   Engrossed  2019-02-27
# 4953  1169754        1630     HJR0017       4      Passed  2019-05-30
# 4957  1178347        1630     HJR0021       4      Passed  2019-05-30
# 4961  1187649        1630     HJR0025       2   Engrossed  2019-02-27
# 4964  1195044        1630     HJR0028       2   Engrossed  2019-05-15
# 8534   CPL. JANSSEN MEMORIAL HIGHWAY
# 8538    ROGER BUSBY MEMORIAL HIGHWAY
# 8542       SGT. GREGORY MEMORIAL RD.
# 8550    CPL. LEOPOLD MEMORIAL BRIDGE
# 8551    SGT. FEEZELL MEMORIAL BRIDGE
# 8553   LCPL J. BASTEAN MEMORIAL SIGN
# 8566  TROOPER HOPKINS MEMORIAL HGWAY
# 8573        PFC KICK MEMORIAL BRIDGE
#
#                                             description  committee_id  \
# 199   Amends the Illinois Vehicle Code. Provides tha...             0
# 4056  Amends the Roadside Memorial Act. Provides tha...           235
# 4213  Amends the General Assembly Operations Act. Pr...             0
# 4537  Congratulates the City of Dixon on the 100th a...             0
# 4930             Amends the House Rules. Adds Rule 9.5.             0
# 4950  Designates the section of Illinois Route 53 th...           254
# 4953  Designates the section of I-294 between mile m...             0
# 4957  Designates Route 16 in Shipman, Illinois as th...             0
# 4961  Designates Illinois Route 143 as it travels fr...           254
# 4964  Designates the portion of Illinois Route 47 ov...           254
# 4965  Designates the portion of Illinois Route 47 ov...           254
# 4969  Designates Old US 50 in Clinton as the "Clinto...           254
# 4998  Designates the Utica River Bridge as the "Ralp...           254
# 5013  Designates the section of Illinois Route 9 bet...           254
# 5014  Designates the Plainfield Road Bridge over Int...             0
# 5017  Designates the section of Illinois Route 59 fr...           235
# 5024  Designates the portion of Illinois Route 111 a...           235
# 5027  Designates West Delmar Avenue in Godfrey as it...           235
# 5032  Designates Illinois Route 143 as it travels fr...             0
# 5033  Designates Old US 50 in Clinton as the "Clinto...             0
# 5034  Designates the section of Route 6 in the City ...             0
# 5035  Designates the section of Route 6 in the City ...             0
# 6258  Amends the Illinois Vehicle Code. Provides tha...             0
# 6319  Amends the Cemetery Oversight Act. Provides th...             0
# 8525  Designates Illinois State Route 51 in Oconee i...           235
# 8527  Designates the section of I-294 between mile m...           254
# 8534  Designate the section of Interstate 39 in Illi...           254
# 8538  Designates Illinois Route 49 from US Route 36 ...           254
# 8542  Designates Route 16 in Shipman to the Southwes...           254
# 8550  Designates the West Baltimore Street Bridge ov...           254
# 8551  Designates the West Baltimore Street Bridge ov...           254
# 8553  Requests that the Illinois Department of Trans...           254
# 8566  Designates Illinois Route 3 in Waterloo from G...           254
# 8573  Designates the IL Route 54 bridge crossing the...           254
#
#                committee last_action_date  \
# 199                  NaN       2019-02-21
# 4056         House Rules       2020-01-13
# 4213                 NaN       2020-01-24
# 4537                 NaN       2019-04-09
# 4930                 NaN       2020-01-24
# 4950  Senate Assignments       2019-03-13
# 4953                 NaN       2019-05-30
# 4957                 NaN       2019-05-30
# 4961  Senate Assignments       2019-03-13
# 4964  Senate Assignments       2020-01-08
# 4965  Senate Assignments       2020-01-08
# 4969  Senate Assignments       2019-04-03
# 4998  Senate Assignments       2019-05-31
# 5013  Senate Assignments       2019-05-28
# 5014                 NaN       2019-05-30
# 5017         House Rules       2019-07-02
# 5024         House Rules       2019-10-30
# 5027         House Rules       2019-10-30
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100344 entries, 0 to 100343
# Data columns (total 5 columns):
# bill_id     100344 non-null int64
# date        100344 non-null object
# chamber     100344 non-null object
# sequence    100344 non-null int64
# action      100344 non-null object
# dtypes: int64(2), object(3)
# memory usage: 3.8+ MB

# %%
history.groupby('bill_id').agg({'sequence': 'max'})
# Out:
#          sequence
# bill_id
# 1144206         6
# 1144207        29
# 1144208         5
# 1144209         8
# 1144210        87
# ...           ...
# 1319756         1
# 1319765         1
# 1319775         1
# 1319784         1
# 1319941         1
#
# [8588 rows x 1 columns]

# %%
roll_calls = pd.read_csv('./IL/2019-2020_101st_General_Assembly/csv/rollcalls.csv')

# %%
roll_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1908 entries, 0 to 1907
# Data columns (total 10 columns):
# bill_id         1908 non-null int64
# roll_call_id    1908 non-null int64
# date            1908 non-null object
# chamber         1908 non-null object
# description     1908 non-null object
# yea             1908 non-null int64
# nay             1908 non-null int64
# nv              1908 non-null int64
# absent          1908 non-null int64
# total           1908 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 149.2+ KB

# %%
roll_calls.description.value_counts()
# Out:
# Third Reading in Senate      765
# Third Reading in House       742
# Concurrence in Senate        187
# Concurrence in House         113
# Motion in House               58
# Motion To Adopt in Senate     37
# Motion in Senate               3
# Amendments in Senate           1
# Agreed Bill List in House      1
# Amendments in House            1
# Name: description, dtype: int64

# %%
at_least_one_nay = roll_calls[roll_calls.nay > 0]

# %%
roll_calls[(roll_calls.yea + roll_calls.nay + roll_calls.nv + roll_calls.absent) == roll_calls.total]
# Out:
#       bill_id  roll_call_id        date chamber                description  \
# 0     1144210        836064  2019-04-04   House     Third Reading in House
# 1     1144210        870733  2019-05-23  Senate    Third Reading in Senate
# 2     1144210        874121  2019-05-29   House       Concurrence in House
# 3     1144210        874122  2019-05-29   House       Concurrence in House
# 4     1144231        841925  2019-04-11   House     Third Reading in House
# ...       ...           ...         ...     ...                        ...
# 1903  1275634        896354  2019-11-14  Senate    Third Reading in Senate
# 1904  1275870        895874  2019-10-30   House     Third Reading in House
# 1905  1278135        896343  2019-11-13  Senate  Motion To Adopt in Senate
# 1906  1280321        896454  2019-11-14   House            Motion in House
# 1907  1280321        896455  2019-11-14  Senate  Motion To Adopt in Senate
#
#       yea  nay  nv  absent  total
# 0     112    0   0       1    113
# 1      58    0   1       0     59
# 2     118    0   0       0    118
# 3     118    0   0       0    118
# 4      91   22   1       0    114
# ...   ...  ...  ..     ...    ...
# 1903   48    1  10       0     59
# 1904   86   25   3       1    115
# 1905   53    0   6       0     59
# 1906  111    4   0       0    115
# 1907   32   18   9       0     59
#
# [1908 rows x 10 columns]

# %%
roll_calls[roll_calls.chamber == 'Senate'].nv.value_counts()
# Out:
# 1     136
# 2     132
# 3     130
# 5     130
# 4     122
# 0      82
# 6      71
# 7      48
# 9      32
# 8      30
# 10     24
# 11     19
# 12     11
# 13      6
# 17      4
# 14      3
# 15      3
# 18      3
# 19      3
# 22      2
# 21      1
# 16      1
# Name: nv, dtype: int64

# %%
roll_calls.chamber.value_counts()
# Out:
# Senate    993
# House     915
# Name: chamber, dtype: int64

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1908 entries, 0 to 1907
# Data columns (total 10 columns):
# bill_id         1908 non-null int64
# roll_call_id    1908 non-null int64
# date            1908 non-null object
# chamber         1908 non-null object
# description     1908 non-null object
# yea             1908 non-null int64
# nay             1908 non-null int64
# nv              1908 non-null int64
# absent          1908 non-null int64
# total           1908 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 149.2+ KB

# %%
at_least_one_nay = at_least_one_nay.merge(df, on='bill_id')

# %%
at_least_one_nay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 586 entries, 0 to 585
# Data columns (total 23 columns):
# bill_id             586 non-null int64
# roll_call_id        586 non-null int64
# date                586 non-null object
# chamber             586 non-null object
# description_x       586 non-null object
# yea                 586 non-null int64
# nay                 586 non-null int64
# nv                  586 non-null int64
# absent              586 non-null int64
# total               586 non-null int64
# session_id          586 non-null int64
# bill_number         586 non-null object
# status              586 non-null int64
# status_desc         586 non-null object
# status_date         586 non-null object
# title               586 non-null object
# description_y       586 non-null object
# committee_id        586 non-null int64
# committee           102 non-null object
# last_action_date    586 non-null object
# last_action         586 non-null object
# url                 586 non-null object
# state_link          586 non-null object
# dtypes: int64(10), object(13)
# memory usage: 109.9+ KB

# %%
at_least_one_nay[at_least_one_nay.yea < at_least_one_nay.nay].shape
# Out:
# (5, 23)

# %%
senate_bills = non_memorial[non_memorial.bill_number.str.contains('SB')]

# %%
senate_roll_calls = roll_calls[roll_calls.chamber == 'Senate']

# %%
senate_merged = senate_bills.merge(senate_roll_calls[['bill_id', 'roll_call_id']], on='bill_id', how='left')

# %%
senate_merged.shape
# Out:
# (2679, 15)

# %%
senate_merged.drop_duplicates(subset='bill_id').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2493 entries, 0 to 2678
# Data columns (total 15 columns):
# bill_id             2493 non-null int64
# session_id          2493 non-null int64
# bill_number         2493 non-null object
# status              2493 non-null int64
# status_desc         2493 non-null object
# status_date         2493 non-null object
# title               2493 non-null object
# description         2493 non-null object
# committee_id        2493 non-null int64
# committee           2188 non-null object
# last_action_date    2493 non-null object
# last_action         2493 non-null object
# url                 2493 non-null object
# state_link          2493 non-null object
# roll_call_id        427 non-null float64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 311.6+ KB

# %%
house_bills = non_memorial[non_memorial.bill_number.str.contains('HB')]
house_roll_calls = roll_calls[roll_calls.chamber == 'House']
house_merged = house_bills.merge(house_roll_calls[['bill_id', 'roll_call_id']], on='bill_id', how='left')
house_merged.drop_duplicates(subset='bill_id').roll_call_id.isna().some()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-6f50735d05d1> in <module>
#       2 house_roll_calls = roll_calls[roll_calls.chamber == 'House']
#       3 house_merged = house_bills.merge(house_roll_calls[['bill_id', 'roll_call_id']], on='bill_id', how='left')
# ----> 4 house_merged.drop_duplicates(subset='bill_id').roll_call_id.isna().some()
#
# ~/anaconda3/envs/metis/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'some'

# %%
def get_percent_roll_call(bills_raw, roll_calls):
    bills = bills_raw[~bills_raw.title.str.contains('MEMORIAL-')]
    
    sen_bills = bills[bills.bill_number.str.contains('SB')]
    sen_roll_calls = roll_calls[roll_calls.chamber == 'Senate']
    sen_merged = sen_bills.merge(sen_roll_calls[['bill_id', 'roll_call_id', 'nay']], on='bill_id', how='left')
    sen = sen_merged.drop_duplicates(subset='bill_id')
    sen_with_roll = sen[sen.roll_call_id.isna()].shape[0]
    print('Senate Percentage', sen_with_roll / sen.shape[0])
    
    house_bills = bills[bills.bill_number.str.contains('HB')]
    house_roll_calls = roll_calls[roll_calls.chamber == 'House']
    house_merged = house_bills.merge(house_roll_calls[['bill_id', 'roll_call_id', 'nay']], on='bill_id', how='left')
    house = house_merged.drop_duplicates(subset='bill_id')
    house_with_roll = house[house.roll_call_id.isna()].shape[0]
    print('House Percentage', house_with_roll / house.shape[0])
    
    print('Total:', (house_with_roll + sen_with_roll) / (house.shape[0] + sen.shape[0]))

# %%
roll_calls_101 = pd.read_csv('./IL/2019-2020_101st_General_Assembly/csv/rollcalls.csv')
bills_101 = pd.read_csv('./IL/2019-2020_101st_General_Assembly/csv/bills.csv')
bills_101 = bills_101[~bills_101.title.str.contains('MEMORIAL-')]
roll_calls_101.drop_duplicates(subset='bill_id').shape[0] / bills_101.drop_duplicates(subset=['bill_id']).shape[0]
# Out:
# 0.12153462094337143

# %%
roll_calls_100 = pd.read_csv('./IL/2017-2018_100th_General_Assembly/csv/rollcalls.csv')
bills_100 = pd.read_csv('./IL/2017-2018_100th_General_Assembly/csv/bills.csv')
bills_100 = bills_100[~bills_100.title.str.contains('MEMORIAL-')]
roll_calls_100.drop_duplicates(subset='bill_id').shape[0] / bills_100.drop_duplicates(subset=['bill_number']).shape[0]
# Out:
# 0.14978304405874499

# %%
roll_calls_99 = pd.read_csv('./IL/2015-2016_99th_General_Assembly/csv/rollcalls.csv')
bills_99 = pd.read_csv('./IL/2015-2016_99th_General_Assembly/csv/bills.csv')
bills_99 = bills_99[~bills_99.title.str.contains('MEMORIAL-')]
roll_calls_99.drop_duplicates(subset='bill_id').shape[0] / bills_99.drop_duplicates(subset=['bill_number']).shape[0]
# Out:
# 0.10903643837525256

# %%
history_100 = pd.read_csv('./IL/2017-2018_100th_General_Assembly/csv/history.csv')
fluff_bills = bills_100[bills_100.description.str.startswith('Mourns') | bills_100.description.str.startswith('Congratulates')]
# history_100 = history_100[]

# %%
bills_100.drop_duplicates(subset=['bill_number']).shape
# Out:
# (11984, 14)

# %%
first = history_100[(history_100.chamber == 'Senate') & history_100.action.str.contains('First Reading') & ~history_100.bill_id.isin(fluff_bills.bill_number)].drop_duplicates(subset=['bill_id'])
second = history_100[(history_100.chamber == 'Senate') & history_100.action.str.contains('Second Reading') & ~history_100.bill_id.isin(fluff_bills.bill_number)].drop_duplicates(subset=['bill_id'])
third = history_100[(history_100.chamber == 'Senate') & history_100.action.str.contains('Third Reading') & ~history_100.bill_id.isin(fluff_bills.bill_number)].drop_duplicates(subset=['bill_id'])

# %%
first.shape
# Out:
# (4496, 5)

# %%
second.shape
# Out:
# (2516, 5)

# %%
third.shape
# Out:
# (2050, 5)

# %%
first.sequence.mean()
# Out:
# 6.602980427046264

# %%
second.sequence.mean()
# Out:
# 18.43998410174881

# %%
second.sequence.std()
# Out:
# 17.423162043275276

# %%
third.sequence.mean()
# Out:
# 24.65170731707317

# %%
third.sequence.std()
# Out:
# 18.616487481832994

# %%
bills_100[bills_100.bill_number.isin(third.bill_id)][['title', 'description']].sample(50)
# Out:
#                                 title  \
# 9378           REGULATORY ACTS-REPEAL
# 8199    NURSES-APRN SCOPE OF PRACTICE
# 4764    COUNTY RECORDER-FEE SCHEDULES
# 9946                  REGULATION-TECH
# 10270    GREENWAYS AND TRAILS COUNCIL
# 4368         SCH CD-DYSLEXIA-HANDBOOK
# 5748   VEH CD-OVERWEIGHT AXLE PERMITS
# 10345               CRIMINAL LAW-TECH
# 732      VEH CD-DEALERSHIP-WINDSHIELD
# 9894     POLICE MEMORIALS SCRATCH-OFF
# 10137     PROBATION-PRETRIAL SERVICES
# 4889             TIF-VILLAGE OF POSEN
# 3211   HOMELESS MINOR-CONSENT;HOUSING
# 3073       FORFEITURE-OWNER STATEMENT
# 10024  AGG ASSAULT&BAT-VET&SERVICEMEM
# 5202        POLICE-VICTIM SENSITIVITY
# 8077                     FINANCE-TECH
# 10633     MHDDAA-FRONT-LINE PERSONNEL
# 10727          PHARMACY-PRESCRIPTIONS
# 10043       PUBLIC FUNDS-CORPORATIONS
# 8082                     FINANCE-TECH
# 5302    SHERIFF'S MERIT BD-DISCIPLINE
# 9525    COMM COLLEGE BOARDS-VACANCIES
# 9950                  REGULATION-TECH
# 10254           STATE GOVERNMENT-TECH
# 5689                KASKASKIA COMMONS
# 10806  SCH CD-LGBT-UNIT OF INSTRCTION
# 8078            GO BOND AUTHORIZATION
# 10471   UTILITY-RETAIL MARKET DEVELOP
# 10847  MEDICAID-NURSING HOME RESIDENT
# 9391   COLLATERAL RECOVERY-EXCEPTIONS
# 10148   AGR-RENEWABLE ENERGY FACILITY
# 10114       CRIM PRO-VIDEO CONFERENCE
# 4658   PEN CD-CHI POL-ANNUAL INCREASE
# 5241              BROWNFIELDS-VARIOUS
# 9967            STATE GOVERNMENT-TECH
# 9856   ELECTED TWP OFFICIALS-EMPLOYEE
# 5749        $ISBE-BROADBAND EXPANSION
# 3031            STATE GOVERNMENT-TECH
# 538     ELEC CD-NUMBER OF ELEC JUDGES
# 3711      CD CORR-CONTENT CONT TABLET
# 9311            HOME BIRTH SAFETY ACT
# 11068  COMMUNITY CARE-HOMEMAKER WAGES
# 9399         CRIM CD-CLOTH-CONCEAL ID
# 3375    DHS-HOME CARE CONSUMER RIGHTS
# Appropriates        464
# Makes               379
# Recognizes          264
# Urges               183
# Declares            132
# Designates           75
# Proposes             48
# Encourages           34
# Repeals              33
# States               26
# Directs              24
# Commends             18
# RESOLVED,            14
# Provides             13
# Honors               12
# Authorizes           12
# Opposes              10
# Condemns              9
# Supports              9
# Calls                 8
# Requests              8
# Recognize             7
# Thanks                6
# Expresses             6
# Appropriations        6
# Resolves              5
# BE                    5
# If                    4
# Reaffirms             4
# Commemorates          4
# Adopts                4
# Celebrates            3
# Recommends            3
# Remembers             2
# Endorses              2
# Designate             2
# Disapproves           2
# Denounces             2
# Appoints              2
# Strongly              2
# Extends               2
# Acknowledges          2
# Stands                2
# Sets                  2
# Reminds               2
# Contains              2
# Instructs             2
# Pledges               2
# Requires              1
# Asks                  1
# John                  1
# Rescinds              1
# Believes              1
# Congratulations       1
# Encourage             1
# Protect               1
# Memorial              1
# FY19                  1
# Admonishes            1
# Morns                 1
# Declare               1
# Re-enacts             1
# Repudiates            1
# Removes               1
# Performance           1
# Salutes               1
# That                  1
# Approves              1
# Commits               1
# Elects                1
# State                 1
# Applauds              1
# University            1
# Proclaims             1
# Reconstitutes         1
# Illinois              1
# Invites               1
# Cautions              1
# Name: first_word, dtype: int64

# %% [markdown]
# # What happens btwn 2nd and 3rd Reading?

# %%
history_100.action.value_counts()[0:80]
# Out:
# First Reading                                                                  11361
# Session Sine Die                                                                8638
# Referred to Rules Committee                                                     7443
# Referred to Assignments                                                         4719
# Rule 19(a) / Re-referred to Rules Committee                                     4118
# Resolution Adopted                                                              3413
# Second Reading - Short Debate                                                   3301
# Second Reading                                                                  2517
# Assigned to Executive Committee                                                 2481
# Filed with Secretary                                                            2298
# Referred to Resolutions Consent Calendar                                        2120
# Co-Sponsor All Senators                                                         2095
# Placed on Calendar 2nd Reading - Short Debate                                   1936
# Placed on Calendar Order of 3rd Reading - Short Debate                          1664
# Do Pass / Short Debate Executive Committee; 011-000-000                         1481
# Rule 3-9(a) / Re-referred to Assignments                                        1337
# Passed Both Houses                                                              1281
# Sent to the Governor                                                            1273
# Governor Approved                                                               1130
# Arrived in House                                                                1106
# Assigned to Executive                                                           1032
# Placed on Calendar 2nd Reading - Short Debate **                                1019
# Held on Calendar Order of Second Reading - Short Debate **                      1009
# Filed with the Clerk by Rep. Michael J. Madigan                                  980
# Placed on Calendar Agreed Resolutions                                            967
# Arrive in Senate                                                                 916
# House Committee Amendment No. 1 Referred to Rules Committee                      842
# Filed with the Clerk by Rep. Jim Durkin                                          771
# Held on Calendar Order of Second Reading - Short Debate                          732
# Rule 2-10 Third Reading Deadline Established As May 31, 2017                     690
# Placed on Calendar Order of 2nd Reading March 28, 2017                           674
# Filed with Secretary by Sen. John J. Cullerton                                   631
# Chief Sponsor Changed to Sen. William E. Brady                                   609
# Rule 19(b) / Re-referred to Rules Committee                                      598
# Senate Floor Amendment No. 1 Referred to Assignments                             587
# Senate Committee Amendment No. 1 Referred to Assignments                         586
# Do Pass Executive; 014-000-000                                                   585
# Placed on Calendar Order of 3rd Reading March 29, 2017                           576
# Placed on Calendar Order of First Reading                                        573
# Pursuant to Senate Rule 3-9(b) / Referred to Assignments                         548
# House Floor Amendment No. 1 Referred to Rules Committee                          534
# Placed on Calendar 2nd Reading - Short Debate ***                                529
# Held on Calendar Order of Second Reading - Short Debate ***                      498
# Assigned to Revenue & Finance Committee                                          495
# Assigned to Judiciary - Criminal Committee                                       491
# Approved for Consideration Assignments                                           470
# Recalled to Second Reading                                                       462
# Placed on Calendar Order of 3rd Reading                                          448
# Re-referred to Assignments                                                       413
# Senate Committee Amendment No. 1 Adopted                                         353
# Rule 2-10 Committee Deadline Established As April 7, 2017                        341
# Added Co-Sponsor Rep. Camille Y. Lilly                                           330
# 3/5 Vote Required                                                                330
# Placed on Calendar Order of Resolutions                                          329
# House Floor Amendment No. 2 Referred to Rules Committee                          321
# House Floor Amendment No. 1 Adopted                                              317
# Filed with Secretary by Sen. Christine Radogno                                   316
# Senate Floor Amendment No. 2 Referred to Assignments                             304
# Final Action Deadline Extended-9(b) May 31, 2017                                 297
# Assigned to Human Services Committee                                             290
# Assigned to Judiciary                                                            272
# Placed on Calendar Order of 2nd Reading March 13, 2018                           262
# Rule 2-10 Committee Deadline Established As April 27, 2018                       254
# Final Action Deadline Extended-9(b) May 31, 2018                                 253
# Effective Date January 1, 2019                                                   253
# Filed with Secretary by Sen. William E. Brady                                    252
# Chief Sponsor Changed to Sen. John J. Cullerton                                  240
# Added Co-Sponsor Rep. Linda Chapa LaVia                                          239
# Added Co-Sponsor Rep. Emanuel Chris Welch                                        235
# Do Pass Executive; 009-000-000                                                   232
# Senate Concurs                                                                   223
# Added Co-Sponsor Rep. Katie Stuart                                               222
# Added Co-Sponsor Rep. Deb Conroy                                                 219
# Rule 2-10 Third Reading Deadline Established As May 3, 2018                      217
# Effective Date January 1, 2018                                                   214
# Assigned to State Government                                                     214
# House Floor Amendment No. 2 Adopted                                              213
# Placed on Calendar Order of 3rd Reading April 17, 2018                           211
# Added Co-Sponsor Rep. Silvana Tabares                                            209
# House Committee Amendment No. 1 Rule 19(a) / Re-referred to Rules Committee      204
# Name: action, dtype: int64

# %%
history_100.bill_id
# Out:
# 0          907043
# 1          907043
# 2          907043
# 3          907043
# 4          907043
#            ...
# 178675    1141084
# 178676    1141100
# 178677    1141100
# 178678    1141100
# 178679    1141100
# Name: bill_id, Length: 178680, dtype: int64

# %%
bills_ids_with_third_readings = history_100[history_100.action.str.contains('Third Reading')].bill_id
bills_started_in_senate = history_100[(history_100.sequence == 1) & (history_100.chamber == 'Senate')].bill_id

# %%
history_100[
    history_100.bill_id.isin(bills_ids_with_third_readings) &
    history_100.bill_id.isin(bills_started_in_senate) &
    (history_100.chamber == 'Senate') &
    (history_100.bill_id == 908098)
].groupby(['bill_id', 'chamber', 'sequence']).agg('last').head(150)
# Out:
#                                 date  \
# bill_id chamber sequence
#                 117       House Floor Amendment No. 4 Motion to Concur F...
#                 118       House Floor Amendment No. 4 Motion to Concur R...
#                 119       House Floor Amendment No. 2 Motion to Concur B...
#                 120       House Floor Amendment No. 3 Motion to Concur B...
#                 121       House Floor Amendment No. 4 Motion to Concur B...
#                 122                                       3/5 Vote Required
#                 123       House Floor Amendment No. 2 Senate Concurs 039...
#                 124       House Floor Amendment No. 3 Senate Concurs 039...
#                 125       House Floor Amendment No. 4 Senate Concurs 039...
#                 126                                          Senate Concurs
#                 127                                      Passed Both Houses
#                 128                                    Sent to the Governor
#                 129                                         Governor Vetoed
#                 130                              Placed Calendar Total Veto
#                 131       Motion Filed Override Governor Veto Sen. Heath...
#                 132                                       3/5 Vote Required
#                 133       Override Governor Veto - Senate Passed 039-015...
#                 139                         Both Houses Override Total Veto
#                 140                             Effective Date July 6, 2017
#                 141                   Public Act . . . . . . . . . 100-0021

# %%
bills_ids_with_second_readings = history_100[history_100.action.str.contains('Second Reading')].bill_id
sen_only = history_100[
    history_100.bill_id.isin(bills_ids_with_second_readings) &
    history_100.bill_id.isin(bills_started_in_senate) &
    (history_100.chamber == 'Senate')
]

# %%
bill_id_second_sequence = sen_only[sen_only.action.str.startswith('Second Reading')][['bill_id', 'sequence']]
bill_id_second_sequence = bill_id_second_sequence.rename(columns={'sequence': 'second_seq'})
bill_id_second_sequence = bill_id_second_sequence.groupby('bill_id').agg('last').reset_index()

# %%
bill_id_third_sequence = sen_only[sen_only.action.str.startswith('Third Reading')][['bill_id', 'sequence']]
bill_id_third_sequence = bill_id_third_sequence.rename(columns={'sequence': 'third_seq'})
bill_id_third_sequence = bill_id_third_sequence.groupby('bill_id').agg('last').reset_index()
# sen_only['second_seq'] = sen_only.groupby('bill_id')

# %%
sen_only = sen_only.merge(bill_id_second_sequence, on='bill_id', how='left').merge(bill_id_third_sequence, on='bill_id', how='left')

# %%
sen_only['sec_third_action_diff'] = sen_only.third_seq - sen_only.second_seq

# %%
sen_only.sec_third_action_diff.describe()
# Out:
# count    23371.000000
# mean         9.079329
# std          8.805182
# min          2.000000
# 25%          2.000000
# 50%          6.000000
# 75%         12.000000
# max         51.000000
# Name: sec_third_action_diff, dtype: float64

# %%
len(sen_only[~sen_only.second_seq.isna()].bill_id.unique())
# Out:
# 1748

# %%
len(sen_only[~sen_only.third_seq.isna()].bill_id.unique())
# Out:
# 883

# %%
sen_only['max_seq'] = sen_only.groupby('bill_id').sequence.transform('last')

# %%
sen_only.head()
# Out:
#    bill_id        date chamber  sequence  \
# 0   907435  2017-01-11  Senate         1
# 1   907435  2017-01-11  Senate         2
# 2   907435  2017-01-11  Senate         3
# 3   907435  2017-01-24  Senate         4
# 4   907435  2017-02-21  Senate         5
#
#                                               action  second_seq  third_seq  \
# 0   Filed with Secretary by Sen. Michael E. Hastings          12       15.0
# 1                                      First Reading          12       15.0
# 2                            Referred to Assignments          12       15.0
# 3                              Assigned to Judiciary          12       15.0
# 4  Senate Committee Amendment No. 1 Filed with Se...          12       15.0
#
#    sec_third_action_diff  max_seq
# 0                    3.0       34
# 1                    3.0       34
# 2                    3.0       34
# 3                    3.0       34
# 4                    3.0       34

# %%
sen_only['perc_btwn_second_third'] = sen_only.sec_third_action_diff / sen_only.max_seq

# %%
sen_only.groupby('bill_id').agg({ 'perc_btwn_second_third': 'last'}).reset_index().perc_btwn_second_third
# Out:
# 0       0.088235
# 1            NaN
# 2       0.463415
# 3       0.285714
# 4            NaN
#           ...
# 1743    0.214286
# 1744    0.083333
# 1745         NaN
# 1746    0.117647
# 1747    0.101695
# Name: perc_btwn_second_third, Length: 1748, dtype: float64

# %%
plt.hist(sen_only.groupby('bill_id').agg({ 'perc_btwn_second_third': 'last'}).reset_index().perc_btwn_second_third)
plt.title('Percent of actions that happened btwn second and third readings');
# Out:
# /Users/willyraedy/anaconda3/envs/metis/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/willyraedy/anaconda3/envs/metis/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sen_only['before_second'] = sen_only.sequence < sen_only.second_seq

# %%
sen_only['perc_before_second'] = (sen_only.second_seq - 1) / sen_only.max_seq

# %%
plt.hist(sen_only.groupby('bill_id').agg({ 'perc_before_second': 'last'}).reset_index().perc_before_second)
plt.title('Percent of actions before Second Reading');

# %%
sen_only['perc_after_third'] = (sen_only.max_seq - sen_only.third_seq) / sen_only.max_seq

# %%
plt.hist(sen_only.groupby('bill_id').agg({ 'perc_after_third': 'last'}).reset_index().perc_after_third)
plt.title('Percent of actions After Third Reading');
# Out:
# /Users/willyraedy/anaconda3/envs/metis/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/willyraedy/anaconda3/envs/metis/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sen_only['ratio_before_btwn'] = sen_only.perc_before_second / sen_only.perc_btwn_second_third

# %%
plt.hist(sen_only.groupby('bill_id').agg({ 'ratio_before_btwn': 'last'}).reset_index().ratio_before_btwn, bins=21)
plt.title('Ratio of Before 2nd and Between Third');
# Out:
# /Users/willyraedy/anaconda3/envs/metis/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/willyraedy/anaconda3/envs/metis/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sen_only['ratio_before_btwn'].describe([.1, .15, .25, .5, .75, .9])
# Out:
# count    23371.000000
# mean         2.959189
# std          2.874026
# min          0.117647
# 10%          0.375000
# 15%          0.461538
# 25%          0.705882
# 50%          2.312500
# 75%          4.000000
# 90%          6.500000
# max         22.500000
# Name: ratio_before_btwn, dtype: float64

# %%
sen_only['ratio_before_btwn'].quantile(.17)
# Out:
# 0.5

# %%
by_bill = sen_only.groupby('bill_id').agg({ 'ratio_before_btwn': 'last'}).reset_index()

# %%
by_bill.ratio_before_btwn.describe()
# Out:
# count    883.000000
# mean       3.053078
# std        2.508070
# min        0.117647
# 25%        1.097222
# 50%        3.000000
# 75%        4.000000
# max       22.500000
# Name: ratio_before_btwn, dtype: float64

# %%
sen_by_bill = sen_only.groupby('bill_id').agg('last')

# %%
sen_by_bill.shape
# Out:
# (1748, 13)

# %%
sen_by_bill[~sen_by_bill.third_seq.isna()].shape
# Out:
# (883, 13)

# %%
883 / 1748
# Out:
# 0.5051487414187643
